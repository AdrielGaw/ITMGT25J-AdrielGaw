# %%
#Problem 1

rows = int(input("Enter number of rows: "))

print("<table>")

for i in range(1,rows+1):
    if i%2 == 0:
        print('<tr class="whiterow"><td>'+str(i)+'</td><td>'+str(i**2)+'</td></tr>')
    else:
        print('<tr class="lightyellowrow"><td>'+str(i)+'</td><td>'+str(i**2)+'</td></tr>')
        
print("</table>")
# Out:
# Enter number of rows: 5
# <table>
# <tr class="lightyellowrow"><td>1</td><td>1</td></tr>
# <tr class="whiterow"><td>2</td><td>4</td></tr>
# <tr class="lightyellowrow"><td>3</td><td>9</td></tr>
# <tr class="whiterow"><td>4</td><td>16</td></tr>
# <tr class="lightyellowrow"><td>5</td><td>25</td></tr>
# </table>

# %%
#Problem 2
day = int(input("Day: "))
month = int(input("Month: "))
year = int(input("Year: "))

month_list = ["January","February","March","April","May","June","July","August","September","October","November","December"]

leapyear = False
if year%4==0:
    leapyear = True
if year%100==0:
    if year%400==0:
        leapyear = True
    else:
        leapyear = False
        
if month < 1 or month > 12:
    print("Date is not valid")

else:
    month_word = month_list[month-1]
    
    if month in [4,6,9,11]:
        if day < 1 or day > 30:
            print("Date is not valid")
        elif day % 10 == 1:
            print("It is the "+str(day)+"st day of the month of "+month_word+" of the year "+str(year))
        elif day % 10 == 2:
            print("It is the "+str(day)+"nd day of the month of "+month_word+" of the year "+str(year))
        elif day % 10 == 3:
            print("It is the "+str(day)+"rd day of the month of "+month_word+" of the year "+str(year))
        else:
            print("It is the "+str(day)+"th day of the month of "+month_word+" of the year "+str(year))
            
    elif month in [1,3,5,7,8,10,12]:
        if day < 1 or day > 31:
            print("Date is not valid")
        elif day % 10 == 1:
            print("It is the "+str(day)+"st day of the month of "+month_word+" of the year "+str(year))
        elif day % 10 == 2:
            print("It is the "+str(day)+"nd day of the month of "+month_word+" of the year "+str(year))
        elif day % 10 == 3:
            print("It is the "+str(day)+"rd day of the month of "+month_word+" of the year "+str(year))
        else:
            print("It is the "+str(day)+"th day of the month of "+month_word+" of the year "+str(year))
            
    elif month == 2:
        if leapyear == True:
            if day < 1 or day > 29:
                print("Date is not valid")
            elif day % 10 == 1:
                print("It is the "+str(day)+"st day of the month of "+month_word+" of the year "+str(year))
            elif day % 10 == 2:
                print("It is the "+str(day)+"nd day of the month of "+month_word+" of the year "+str(year))
            elif day % 10 == 3:
                print("It is the "+str(day)+"rd day of the month of "+month_word+" of the year "+str(year))
            else:
                print("It is the "+str(day)+"th day of the month of "+month_word+" of the year "+str(year))
        elif leapyear == False:
            if day < 1 or day > 28:
                print("Date is not valid")
            elif day % 10 == 1:
                print("It is the "+str(day)+"st day of the month of "+month_word+" of the year "+str(year))
            elif day % 10 == 2:
                print("It is the "+str(day)+"nd day of the month of "+month_word+" of the year "+str(year))
            elif day % 10 == 3:
                print("It is the "+str(day)+"rd day of the month of "+month_word+" of the year "+str(year))
            else:
                print("It is the "+str(day)+"th day of the month of "+month_word+" of the year "+str(year))
# Out:
# Day: 31
# Month: 12
# Year: 1234
# It is the 31st day of the month of December of the year 1234

# %%
#Problem 3
def obedient(num):
    if num%3 == 0:
        return True
    else:
        return False

print(obedient(69))
# Out:
# True

# %%
#Problem 4
def multtable(x):
    for i in range(1,x+1):
        for j in range(1,x+1):
            print(i*j,end="\t")
        print("")

multtable(8)
# Out:
# 1	2	3	4	5	6	7	8
# 2	4	6	8	10	12	14	16
# 3	6	9	12	15	18	21	24
# 4	8	12	16	20	24	28	32
# 5	10	15	20	25	30	35	40
# 6	12	18	24	30	36	42	48
# 7	14	21	28	35	42	49	56
# 8	16	24	32	40	48	56	64

# %%
#Problem 5

while True:
    fire = 0
    earth = 0
    water = 0
    
    q1 = input("Do you prefer (a) the mountains, (b) the city, or (c) the beach? ")
    if q1 == "a" or q1 == "b" or q1 == "c":
        if q1 == "a":
            fire += 1 
        elif q1 == "b":
            earth += 1
        elif q1 == "c":
            water += 1
    else:
        print("Sorry, you inputted a wrong letter. Please start again.")
        continue
    
    
    
    q2 = input("Do you prefer (a) yoghurt, (b) ice cream, or (c) gelato? ")
    if q2 == "a" or q2 == "b" or q2 == "c":
        if q2 == "a":
            earth += 1
        elif q2 == "b":
            water += 1
        elif q2 == "c":
            fire += 1
    else:
        print("Sorry, you inputted a wrong letter. Please start again.")
        continue
    
    
    
    q3 = input("Do you prefer (a) reading, (b) singing, or (c) writing? ")    
    if q3 == "a" or q3 == "b" or q3 == "c":
        if q3 == "a":
            water += 1
        elif q3 == "b":
            fire += 1
        elif q3 == "c":
            earth += 1
    else:
        print("Sorry, you inputted a wrong letter. Please start again.")
        continue
    
    
    
    q4 = input("Do you prefer (a) sweet, (b) salty, or (c) spicy food? ")    
    if q4 == "a" or q4 == "b" or q4 == "c":
        if q4 == "a":
            earth += 1
        elif q4 == "b":
            water += 1
        elif q4 == "c":
            fire += 1
    else:
        print("Sorry, you inputted a wrong letter. Please start again.")
        continue
    
    
    
    q5 = input("Do you prefer (a) cats, (b) dogs, or (c) fish? ")    
    if q5 == "a" or q5 == "b" or q5 == "c":
        if q5 == "a":
            earth += 1
        elif q5 == "b":
            fire += 1
        elif q5 == "c":
            water += 1
        break
    else:
        print("Sorry, you inputted a wrong letter. Please start again.")
        continue

        
        
#COMPARE


if fire > water and fire > earth:
    print("Your element is Fire")
elif water > fire and water > earth:
    print("Your element is Water")
elif earth > fire and earth > water:
    print("Your element is Earth")
elif fire == earth:
    print("Your element is Earth")
elif fire == water:
    print("Your element is Fire")
elif earth == water:
    print("Your element is Water")
# Out:
# Do you prefer (a) the mountains, (b) the city, or (c) the beach? b
# Do you prefer (a) yoghurt, (b) ice cream, or (c) gelato? b
# Do you prefer (a) reading, (b) singing, or (c) writing? b
# Do you prefer (a) sweet, (b) salty, or (c) spicy food? b
# Do you prefer (a) cats, (b) dogs, or (c) fish? asdfasdfasdf
# Sorry, you inputted a wrong letter. Please start again.
# Do you prefer (a) the mountains, (b) the city, or (c) the beach? b
# Do you prefer (a) yoghurt, (b) ice cream, or (c) gelato? b
# Do you prefer (a) reading, (b) singing, or (c) writing? b
# Do you prefer (a) sweet, (b) salty, or (c) spicy food? b
# Do you prefer (a) cats, (b) dogs, or (c) fish? b
# Your element is Fire
